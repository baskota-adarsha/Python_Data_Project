# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()


# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month']=df['job_posted_date'].dt.strftime('%b')
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0                                                    None              Jun
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...              Oct
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...              Jul
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...              Aug
# ...                                                   ...              ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 785738         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 785740              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [785741 rows x 18 columns]

# %%
months=df['job_posted_month'].unique()
dict_months= {month:df[df['job_posted_month']==month] for month in months}
dict_months['Jun']
# Out:
#                   job_title_short  \
# 0            Senior Data Engineer
# 8                Business Analyst
# 16                  Data Engineer
# 17                 Data Scientist
# 24                 Data Scientist
# ...                           ...
# 785347             Data Scientist
# 785571               Data Analyst
# 785617               Data Analyst
# 785669  Machine Learning Engineer
# 785675               Data Analyst
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 8                Technology & Operations Business Analyst
# 16                                      Big Data Engineer
# 17                                 Data Science Team Lead
# 24                          Data Scientist (DataLab Team)
# ...                                                   ...
# 785347                    Practicante Científico de Datos
# 785571  Credits Monitoring and Reporting Analytics Spe...
# 785617                                       Data Analyst
# 785669                   Senior Machine Learning Engineer
# 785675                          Quantitative Data Analyst
#
#                     job_location  \
# 0                  Watertown, CT
# 8            Copenhagen, Denmark
# 16      Pune, Maharashtra, India
# 17                    Laurel, MD
# 24                      Anywhere
# ...                          ...
# 785347                      Peru
# 785571                   Türkiye
# 785617          Lisbon, Portugal
# 785669            Warsaw, Poland
# 785675                     Italy
#
#                                                   job_via job_schedule_type  \
# 0                                         via Work Nearby         Full-time
# 8                                         via Trabajo.org         Full-time
# 16                                           via LinkedIn         Full-time
# 17      via APL Careers - Johns Hopkins University App...         Full-time
# 24                                           via LinkedIn         Full-time
# ...                                                   ...               ...
# 785347      via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 785571                                    via Trabajo.org         Full-time
# 785617                           via Empregos Trabajo.org         Full-time
# 785669                              via Praca Trabajo.org         Full-time
# 785675                             via Lavoro Trabajo.org         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 0                    False  Texas, United States 2023-06-16 13:44:15
# 8                    False               Denmark 2023-06-05 13:44:34
# 16                   False                 India 2023-06-15 13:28:03
# 17                   False               Georgia 2023-06-13 13:25:17
# 24                    True                Serbia 2023-06-27 13:46:46
# ...                    ...                   ...                 ...
# 785347               False                  Peru 2023-06-29 07:09:12
# 785571               False                Turkey 2023-06-10 06:33:28
# 785617               False              Portugal 2023-06-28 06:51:12
# 785669               False                Poland 2023-06-07 06:18:29
# 785675               False                 Italy 2023-06-08 07:43:38
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 8                       False                 False        Denmark
# 16                      False                 False          India
# 17                      False                  True  United States
# 24                      False                 False         Serbia
# ...                       ...                   ...            ...
# 785347                  False                 False           Peru
# 785571                  False                 False         Turkey
# 785617                   True                 False       Portugal
# 785669                  False                 False         Poland
# 785675                   True                 False          Italy
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0             None              NaN              NaN
# 8             None              NaN              NaN
# 16            None              NaN              NaN
# 17            None              NaN              NaN
# 24            None              NaN              NaN
# ...            ...              ...              ...
# 785347        None              NaN              NaN
# 785571        None              NaN              NaN
# 785617        None              NaN              NaN
# 785669        None              NaN              NaN
# 785675        None              NaN              NaN
#
#                                     company_name  \
# 0                           Boehringer Ingelheim
# 8                                         Hempel
# 16                         Hexaware Technologies
# 17      Johns Hopkins Applied Physics Laboratory
# 24                                       Semrush
# ...                                          ...
# 785347                                      Byte
# 785571                      NBS İnsan Kaynakları
# 785617                                  Onrising
# 785669               Digital Hub Warsaw At Bayer
# 785675                             Confidenziale
#
#                                                job_skills  \
# 0                                                    None
# 8                     ['excel', 'powerpoint', 'power bi']
# 16      ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 17                                 ['go', 'apl', 'excel']
# 24                                             ['python']
# ...                                                   ...
# 785347             ['python', 'sql', 'airflow', 'docker']
# 785571                     ['sas', 'sas', 'sql', 'excel']
# 785617                       ['sql', 'excel', 'power bi']
# 785669  ['python', 'aws', 'gcp', 'azure', 'tensorflow'...
# 785675                   ['aws', 'airflow', 'confluence']
#
#                                           job_type_skills job_posted_month
# 0                                                    None              Jun
# 8       {'analyst_tools': ['excel', 'powerpoint', 'pow...              Jun
# 16      {'cloud': ['databricks', 'azure'], 'databases'...              Jun
# 17      {'analyst_tools': ['excel'], 'programming': ['...              Jun
# 24                            {'programming': ['python']}              Jun
# ...                                                   ...              ...
# 785347  {'libraries': ['airflow'], 'other': ['docker']...              Jun
# 785571  {'analyst_tools': ['sas', 'excel'], 'programmi...              Jun
# 785617  {'analyst_tools': ['excel', 'power bi'], 'prog...              Jun
# 785669  {'cloud': ['aws', 'gcp', 'azure'], 'libraries'...              Jun
# 785675  {'async': ['confluence'], 'cloud': ['aws'], 'l...              Jun
#
# [61572 rows x 18 columns]

# %%
df_q1=pd.concat([dict_months['Jan'],dict_months['Feb'],dict_months['Mar']],ignore_index=True)
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-01-14 13:18:07                  False                 False
# 1      2023-01-31 13:53:38                  False                 False
# 2      2023-01-25 13:24:01                  False                 False
# 3      2023-01-28 13:07:30                  False                  True
# 4      2023-01-03 23:02:27                  False                 False
# ...                    ...                    ...                   ...
# 220479 2023-03-13 06:16:16                  False                 False
# 220480 2023-03-12 06:18:18                  False                 False
# 220481 2023-03-12 06:32:36                  False                 False
# 220482 2023-03-12 06:32:15                  False                 False
# 220483 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico        None              NaN              NaN
# 1             Belgium        None              NaN              NaN
# 2       United States        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4              Brazil        None              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore        None              NaN              NaN
# 220480        Germany        None              NaN              NaN
# 220481       Malaysia        None              NaN              NaN
# 220482          Sudan        None              NaN              NaN
# 220483          India        None              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_q1.to_csv('quarter 1.csv')

# %%
pd.read_csv("quarter 1.csv",index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-01-14 13:18:07                  False                 False
# 1       2023-01-31 13:53:38                  False                 False
# 2       2023-01-25 13:24:01                  False                 False
# 3       2023-01-28 13:07:30                  False                  True
# 4       2023-01-03 23:02:27                  False                 False
# ...                     ...                    ...                   ...
# 220479  2023-03-13 06:16:16                  False                 False
# 220480  2023-03-12 06:18:18                  False                 False
# 220481  2023-03-12 06:32:36                  False                 False
# 220482  2023-03-12 06:32:15                  False                 False
# 220483  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %%
df_q1.to_excel('quarter1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_q1.to_excel('quarter1.xlsx')
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)   2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\formats\excel.py:962, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
# --> 962         writer.close()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\worksheet\_writer.py:359, in WorksheetWriter.write(self)
#     355 """
#     356 High level
#     357 """
#     358 self.write_top()
# --> 359 self.write_rows()
#     360 self.write_tail()
#     361 self.close()
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\worksheet\_writer.py:125, in WorksheetWriter.write_rows(self)
#     123 with xf.element("sheetData"):
#     124     for row_idx, row in self.rows():
# --> 125         self.write_row(xf, row, row_idx)
#     127 self.xf.send(None)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\worksheet\_writer.py:147, in WorksheetWriter.write_row(self, xf, row, row_idx)
#     141 if (
#     142     cell._value is None
#     143     and not cell.has_style
#     144     and not cell._comment
#     145     ):
#     146     continue
# --> 147 write_cell(xf, self.ws, cell, cell.has_style)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openpyxl\cell\_writer.py:86, in etree_write_cell(xf, worksheet, cell, styled)
#      83     if value is not None:
#      84         cell_content.text = safe_string(value)
# ---> 86 xf.write(el)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\et_xmlfile\xmlfile.py:120, in _IncrementalFileWriter.write(self, arg)
#     118     default_ns_attr_prefix = None
#     119     uri_to_prefix = {}
# --> 120 incremental_tree._serialize_ns_xml(
#     121     self._file,
#     122     arg,
#     123     nsmap_scope=nsmap_scope,
#     124     global_nsmap=self.global_nsmap,
#     125     short_empty_elements=True,
#     126     is_html=self.is_html,
#     127     is_root=is_root,
#     128     uri_to_prefix=uri_to_prefix,
#     129     default_ns_attr_prefix=default_ns_attr_prefix,
#     130 )
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\et_xmlfile\incremental_tree.py:613, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     566 def _serialize_ns_xml(
#     567     write,
#     568     elem,
#    (...)    577     **kwargs,
#     578 ):
#     579     """Serialize an element or tree using 'write' for output.
#     580
#     581     Args:
#    (...)    605             New prefix -> uri mapping to be applied to this element.
#     606     """
#     607     (
#     608         tag,
#     609         nsmap_scope,
#     610         default_ns_attr_prefix,
#     611         uri_to_prefix,
#     612         next_remains_root,
# --> 613     ) = write_elem_start(
#     614         write,
#     615         elem,
#     616         nsmap_scope,
#     617         global_nsmap,
#     618         short_empty_elements,
#     619         is_html,
#     620         is_root,
#     621         uri_to_prefix,
#     622         default_ns_attr_prefix,
#     623         new_nsmap=new_nsmap,
#     624     )
#     625     for e in elem:
#     626         _serialize_ns_xml(
#     627             write,
#     628             e,
#    (...)    636             new_nsmap=None,
#     637         )
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\et_xmlfile\incremental_tree.py:539, in write_elem_start(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     537         write("".join([f' {k}="{ET._escape_attrib_html(v)}"' for k, v in item_parts]))
#     538     else:
# --> 539         write("".join([f' {k}="{ET._escape_attrib(v)}"' for k, v in item_parts]))
#     540 if is_html:
#     541     write(">")
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\xml\etree\ElementTree.py:1034, in _escape_attrib(text)
#    1031     except (TypeError, AttributeError):
#    1032         _raise_serialization_error(text)
# -> 1034 def _escape_attrib(text):
#    1035     # escape attribute value
#    1036     try:
#    1037         if "&" in text:
#
# KeyboardInterrupt:

# %%
df.to_parquet('jobs_data.parquet')

# %%
df.to_pickle('job_data.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.to_pickle('job_data.pkl')
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:3187, in NDFrame.to_pickle(self, path, compression, protocol, storage_options)
#    3137 """
#    3138 Pickle (serialize) object to file.
#    3139
#    (...)   3183 4    4    9
#    3184 """  # noqa: E501
#    3185 from pandas.io.pickle import to_pickle
# -> 3187 to_pickle(
#    3188     self,
#    3189     path,
#    3190     compression=compression,
#    3191     protocol=protocol,
#    3192     storage_options=storage_options,
#    3193 )
#
# File c:\Users\AdarshaB\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\pickle.py:111, in to_pickle(obj, filepath_or_buffer, compression, protocol, storage_options)
#     101     protocol = pickle.HIGHEST_PROTOCOL
#     103 with get_handle(
#     104     filepath_or_buffer,
#     105     "wb",
#    (...)    109 ) as handles:
#     110     # letting pickle write directly to the buffer is more memory-efficient
# --> 111     pickle.dump(obj, handles.handle, protocol=protocol)
#
# KeyboardInterrupt:
# when serializing list item 3546736
# when serializing tuple item 4
# when serializing numpy.ndarray state
# when serializing numpy.ndarray object
# when serializing tuple item 0
# when serializing pandas.core.internals.blocks.NumpyBlock reconstructor arguments
# when serializing pandas.core.internals.blocks.NumpyBlock object
# when serializing tuple item 3
# when serializing tuple item 0
# when serializing pandas.core.internals.managers.BlockManager reconstructor arguments
# when serializing pandas.core.internals.managers.BlockManager object
# when serializing dict item '_mgr'
# when serializing pandas.core.frame.DataFrame state
# when serializing pandas.core.frame.DataFrame object
